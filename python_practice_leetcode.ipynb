# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmivijay23/python_practices/blob/main/python_practice_leetcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O(n) time complexity — only one loop.
#
# O(1) space complexity — uses just two variables.

# %%
class Solution(object):
    def maxProfit(self, prices):
        """
        :type prices: List[int]
        :rtype: int
        """
        min_price=float('inf')
        max_profit=0
        for price in prices:
            if price < min_price:
                min_price=price
            else:
                max_profit=max(max_profit, price-min_price)
        return max_profit

# %%
obj=Solution()
max_profit=obj.maxProfit([3,5,8,1,9])
max_profit
# Out:
# 8

# %% [markdown]
# ![image.png](data:image/png;base64,...)
